# %% [markdown]
# # Chapter 6 : Understand Your Data With Visualization

# %% [markdown]
# ## Summary
# * Histograms.
# * Density Plots.
# * Box and Whisker Plots.
# * Correlation Matrix Plot.
# * Scatter Plot Matrix.

# %% [markdown]
# We import libs we need for this chapter

# %%
from matplotlib import pyplot
from pandas import read_csv
import numpy
from pandas.plotting import scatter_matrix
import pandas_profiling

# %% [markdown]
# We load the dataset

# %%
filename = "kaggle-house-prices-train.csv"
data = read_csv(filename, index_col=0)

# %% [markdown]
# We select numeric column

# %%
data_num = data.select_dtypes(exclude=['object'])
print(data_num)
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1             60         65.0     8450            7            5       2003
# 2             20         80.0     9600            6            8       1976
# 3             60         68.0    11250            7            5       2001
# 4             70         60.0     9550            7            5       1915
# 5             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1456          60         62.0     7917            6            5       1999
# 1457          20         85.0    13175            6            6       1978
# 1458          70         66.0     9042            7            9       1941
# 1459          20         68.0     9717            5            6       1950
# 1460          20         75.0     9937            5            6       1965
#
# ...

# %% [markdown]
# ## 6.1 Univariate Plots

# %% [markdown]
# ### 6.1.1 Histograms

# %%
fig, ax = pyplot.subplots(10, 4, figsize=(15, 25))
ax_flat = [sub for line in ax for sub in line]
data_num.hist(ax=ax_flat[0:37], bins=25, log=True, bottom=0.1)
ax[0,0].set_xscale('log')
pyplot.show()

# %% [markdown]
# ### 6.1.2 Density Plots

# %%
data_num.plot(kind='density', subplots=True, layout=(10,4), sharex=False, figsize=(15, 25))
pyplot.show()

# %% [markdown]
# ### 6.1.3 Box and Whisker Plots

# %%
data_num.plot(kind='box', subplots=True, layout=(10,4), sharex=False, sharey=False, figsize=(15, 25))
pyplot.show()

# %% [markdown]
# ## 6.2 Multivariate Plots

# %% [markdown]
# ### 6.2.1 Correlation Matrix Plot
# Correlation gives an indication of how related the changes are between two variables. If two
# variables change in the same direction they are positively correlated.

# %%
names = list(data_num)
correlations = data.corr()
fig = pyplot.figure(figsize=(25, 25))
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,37,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names, rotation=40)
ax.set_yticklabels(names)
pyplot.show()

# %% [markdown]
# ### Example of creating a generic correlation matrix plot.

# %%
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
pyplot.show()

# %% [markdown]
# ### 6.2.2 Scatter Plot Matrix
# A scatter plot shows the relationship between two variables as dots in two dimensions, one
# axis for each attribute.

# %%
scatter_matrix(data_num, figsize=(15, 25))
pyplot.show()

# %%
pandas_profiling.ProfileReport(data_num)
# Out:
# C:\Users\utilisateur\Anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...
